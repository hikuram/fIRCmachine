# %%
#minimal dependencies
# !pip install cyipopt
# !pip install pydmf
# !pip install orb-models
# !pip install sella
import os
# !os.environ["JAX_PLATFORM_NAME"] = "cpu"

# %%
# !git clone https://github.com/hikuram/fIRCmachine.git
# !cp fircm/* .

# %%
def upload_as(new_name: str):
    import os
    from google.colab import files

    uploaded_name = [k for k in files.upload().keys()][0]
    os.rename(uploaded_name, new_name)

# %%
# upload input
upload_as("react.xyz")
upload_as("prod.xyz")

# %% [markdown]
# ### ▶ Run

# %%
# !python fIRCmachine.py -r react.xyz -p prod.xyz -d result -c 0 -m orbmol

# %%
# download zip
# !zip -r /content/download.zip /content/result
from google.colab import files
files.download("/content/download.zip")

# %% [markdown]
# ### ⚙ Experimental

# %%
# %env LDFLAGS=-Wl,--no-as-needed -lmvec -lm -lgfortran
# !pip install --no-binary=tblite --no-cache-dir tblite

# %%
# !pip install gpu4pyscf-cuda12x
# !pip install pyscf
# !python -m cupyx.tools.install_library --cuda 12.x --library cutensor

# %%
# !git clone --depth 1 https://github.com/hikuram/redox_benchmark.git
# !pip install --no-deps -e redox_benchmark

# %%
upload_as("input.xyz")
